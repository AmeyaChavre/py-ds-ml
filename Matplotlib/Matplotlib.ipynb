# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
# To display plots inside Jupyter Notebook
# %matplotlib inline

# %%
# Outside Jupyter Notebook 
# Use: 
# plt.show()

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# <Functional Method>

# %%
plt.plot(x,y)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Graph')
# Out:
# Text(0.5, 1.0, 'Graph')

# %%
#Subplots
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'g')

# %%
# <Object Oriented Method>

# %%
fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(x,y)

axes.set_xlabel('X')
axes.set_ylabel('Y')
axes.set_title('Graph')
# Out:
# Text(0.5, 1.0, 'Graph')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y,'r')
axes2.plot(y,x,'g')

axes1.set_title('MAINPLOT')
axes2.set_title('SUBPLOT')
# Out:
# Text(0.5, 1.0, 'SUBPLOT')

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

#axes.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=3,ncols=3)
plt.tight_layout()

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

#for current_axes in axes:
#    current_axes.plot(x,y)

axes[0].plot(x,y)
axes[0].plot(y,x)
axes[0].set_title('First Plot')

axes[1].plot(x,y)
axes[1].plot(y,x)
axes[1].set_title('Second Plot')

plt.tight_layout()

# %% [markdown]
# # Figure Size and DPI

# %%
fig = plt.figure(figsize=(8,2),dpi=100)

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,'r',label='x-y')
ax.plot(y,x,'g',label='y-x')
ax.plot(x*4,y*4,'y',label='x^4-y^4')
ax.plot(x*8,y*8,'b',label='x^8-y^8')

ax.legend(loc=0) 

ax.set_title('MAIN GRAPH')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
fig,axes = plt.subplots(nrows=2,ncols=1,figsize=(8,2),dpi=100)

axes[0].plot(x,y,'r')
axes[0].set_title('Subplot1')

axes[1].plot(x,y,'g')
axes[1].set_title('Subplot2')

plt.tight_layout()

# %%
fig.savefig('graph.png',dpi=200)

# %% [markdown]
# # Plot Customization

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.set_title('US Presidential Election : 2020')
ax.set_xlabel('Days')
ax.set_ylabel('Voter Turnout  (in thousands)')

ax.plot(x,y,color='blue',marker='*',markersize=10,label='Democrats',markerfacecolor='white',markeredgewidth=1.5)
ax.plot(y,x,color='#FF8C00',linewidth=5,alpha=0.5,label='Undecided',marker='*',markeredgecolor='black')
ax.plot(x,x**3,color='red',linestyle=':',marker='*',markersize = 20,label='Republicans',markerfacecolor='white',markeredgewidth=1.5)

ax.legend()

# %% [markdown]
# # Control over axis appearnce
# ### Plot Range

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.set_title('US Presidential Election : 2020')
ax.set_xlabel('Days')
ax.set_ylabel('Voter Turnout  (in thousands)')

ax.plot(x,y,color='blue',marker='*',markersize=10,label='Democrats',markerfacecolor='white',markeredgewidth=1.5)
ax.plot(y,x,color='#FF8C00',linewidth=5,alpha=0.5,label='Undecided',marker='*',markeredgecolor='black')
ax.plot(x,x**3,color='red',linestyle=':',marker='*',markersize = 20,label='Republicans',markerfacecolor='white',markeredgewidth=1.5)

ax.set_xlim([0,5])
ax.set_ylim([0,20])
ax.legend()
